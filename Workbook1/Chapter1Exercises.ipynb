# %% [markdown]
# Exercise 1

# %%
print('Hello world!')
#the letter 'P' should be small
# Out:
# Hello world!

# %%
print('Hello world!')
# missing of open parenthesis (()
# Out:
# Hello world!

# %%
print('Hello world!')
#missing a quotation mark (')
# Out:
# Hello world!

# %%
print('Hello world!')
#has extra quotation mark
# Out:
# Hello world!

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print(x)
#44
# Out:
# 44

# %%
x = 43
#x = X + 1
x = x + 1
print(x)
# variable X has no value, undefined
# Out:
# 44

# %%
# !git config --global user.name =  'YeshaDane' #your full name
# !git config --global user.email = 'yeshadane.cabingan@students.isatu.edu.ph.' #the email address you used in creating your GitHub account
# !git config --global user.password = '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' #password should be the token

# %%
# !git clone https://YeshaDane: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@github.com/YeshaDane/ICT110_CS2A_Cabingan.git
# Out:
# Cloning into 'ICT110_CS2A_Cabingan'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 1), reused 5 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), 24.98 KiB | 12.49 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Another copy of Chapter1Exercises.ipynb" "/content/ICT110_CS2A_Cabingan/Wokbook1"
