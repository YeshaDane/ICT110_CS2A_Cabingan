# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Investigate on the difference between `is` and `==` given the following variables.
# ```python
# a = 2
# b = 2.0
# c = a
# ```

# %%
##a == b and a == c are True because they have the same value (2).
##a is c is True because a and c refer to the same object in memory.
##a is b is False because a and b refer to different objects in memory, even though their values are equivalent.

# %% [markdown]
# ## CHALLENGES

# %% [markdown]
# #### Challenge 1

# %% [markdown]
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.
#
#     Enter a number: 4
#     Enter a number: 5
#     Enter a number: bad data
#     Invalid input
#     Enter a number: 7
#     Enter a number: done
#     16 3 5.333333333333333
#
# [PEW] E5.1

# %%
##answer
total = 0
count = 0

while True:
    num_input = input("Enter a number: ")

    if num_input == 'done':
        break

    try:
        num = float(num_input)
        total += num
        count += 1
    except ValueError:
        print("Invalid input")

if count == 0:
    print("No numbers entered.")
else:
    average = total / count
    print(total, count, average)
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16.0 3 5.333333333333333

# %% [markdown]
# #### Challenge 2

# %% [markdown]
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.
#
# [PEW] E5.2

# %%
numbers = []

while True:
    num_input = input("Enter a number: ")

    if num_input == 'done':
        break

    try:
        num = float(num_input)
        numbers.append(num)
    except ValueError:
        print("Invalid input")

if not numbers:
    print("No numbers entered.")
else:
    max_num = max(numbers)
    min_num = min(numbers)
    print("Maximum:", max_num)
    print("Minimum:", min_num)
# Out:
# Enter a number: 6
# Enter a number: 5
# Enter a number: bad
# Invalid input
# Enter a number: 6
# Enter a number: done
# Maximum: 6.0
# Minimum: 5.0
